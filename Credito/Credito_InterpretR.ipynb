# %% [markdown]
# Estatisticas descritivas:
#
# Com base nos resultados pode se observar que:
#
# Valores ausentes (faltantes): Não há dados ausentes no conjunto de dados, o que é excelente para prosseguir com a análise sem precisar de limpeza de dados.
#
# Variáveis numéricas:
#
# Idade:A  Média idades é de 46 anos e um intervalo entre 26 e 73 anos. Não há valores muito discrepantes.
#
# Dependentes: A maioria dos clientes tem entre 1 a 5 dependentes.
#
# Meses de relacionamento: A média de 35,93 meses (aproximadamente 3 anos) é uma boa métrica de tempo de fidelidade do cliente.
#
# Quantidade de produtos: A maioria dos clientes tem/comprou entre 3 e 6 produtos.
#
# Iterações, meses inativo e transações: Distribuições com algumas variações interessantes, como o maior número de transações de até 139.
#
# Variáveis categóricas:
#
# Sexo: Maioria de clientes é do sexo feminino (F).
#
# Escolaridade: A maior parte tem ensino de Mestrado.
#
# Estado Civil: Maioria é casada.
#
# Salário Anual: A maioria dos clientes ganha menos de $40K ao ano.
#
# Tipo de Cartão: Maioria dos clientes possui o cartão Blue.

# %% [markdown]
# **Interpretação dos Resultados do Primeiro Modelo**
#
# O modelo alcançou uma acurácia de 86,97%, o que indica que ele classificou corretamente cerca de 87% dos casos no conjunto de teste.
#
# 1️⃣ **Precisão (Precision)**
#
# Para não inadimplentes (0): 91% das previsões de "não default" estavam corretas.
#
# Para inadimplentes (1): Apenas 61% das previsões de "default" estavam corretas.
#
# 📌 **Interpretação: O modelo tem alta precisão para prever clientes que NÃO irão dar default, mas tem dificuldades em prever corretamente os clientes que realmente darão default.**
#
# 2️⃣ **Recall (Sensibilidade)**
#
# Para não inadimplentes (0): 93% dos clientes realmente sem default foram corretamente classificados.
#
# Para inadimplentes (1): Apenas 54% dos clientes que deram default foram corretamente identificados.
#
# 📌 **Interpretação: O modelo não está capturando bem os casos de default (1). Com um recall de 54%, significa que 46% dos clientes inadimplentes estão sendo classificados erroneamente como bons pagadores.**
#
# 3️⃣ F1-Score
#
# Para não inadimplentes (0): 0.92 → Um bom equilíbrio entre precisão e recall.
#
# Para inadimplentes (1): 0.57 → O modelo não está muito bom para detectar os clientes que irão dar default.
#
# 📌 **Interpretação: O modelo funciona bem para prever quem NÃO será inadimplente, mas precisa de ajustes para melhorar a identificação de quem será inadimplente.**
#
# 4️⃣ Macro vs. Weighted Averages
# Macro Average (média simples entre as classes):
# Mostra que o modelo tem desempenho desigual entre classes (0.76 de precisão geral vs. 0.73 de recall geral).
#
# Weighted Average (considera o tamanho das classes):
# Indica que o desempenho global é bom para a classe majoritária (não default), mas ruim para a classe minoritária (default).
#
# 📌 O que se pode melhorar?
# 1️⃣ Ajustar o balanceamento das classes: A classe "default" (1) tem menos exemplos, o que pode estar fazendo o modelo priorizar os não inadimplentes. Podemos aplicar técnicas como undersampling, oversampling ou SMOTE para equilibrar as classes.
#
# 2️⃣ Testar hiperparâmetros diferentes: Podemos ajustar os parâmetros do modelo para melhorar a sensibilidade da classe minoritária.
#
# 3️⃣ Tentar outros modelos: O XGBoost e o Random Forest podem oferecer melhores resultados na classificação de clientes inadimplentes.
