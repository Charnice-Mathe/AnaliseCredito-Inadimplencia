# %%
print('testando jupyter')
print('Obrigado Deus')
print('God, you are father of all father and you know that')
print('Have a nice day everyone, iam so happy today')

import numpy as np
import pandas as pd
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
import seaborn as sns

from sklearn.datasets import load_iris
data= load_iris()
df=pd.DataFrame(data=data.data, columns=data.feature_names)
df.head
#or
iris=load_iris()
dados=pd.DataFrame(data=np.c_[iris['data'], iris['target']], columns=iris['feature_names']+['target'])
dados['species']=pd.Categorical.from_codes(iris.target, iris.target_names)

print(dados.head(3))


print('Descricao dos dados')
print(dados.describe())

# Fazer o gráfico de pizza
tabelaFreq = dados.species.value_counts()
print('Frequência absoluta')
print(tabelaFreq)
tabelaFreq.plot.pie(legend=True, autopct='%1.1f%%').set_title('Frequência das especies')
#tabelaFreq.plot.pie(legend=True, autopct='%1.1f%%')


print('Gerando matriz de scatter plots')
classe_cor = {'dados-setosa' : 'red','dados-virginica' : 'blue','dados-versicolor' : 'green'}
scatter_matrix(dados, color= 'green')
pyplot.show()

print('Gerando bloxplot para os atributos da Iris')
dados.plot(kind='box', title='Boxplot')
pyplot.show()

#dados['sepal length (cm)'].mean() para calcular media
# Frequência absoluta
tabelaFreq = dados.species.value_counts()
print('Frequência absoluta')
print(tabelaFreq)

# Fazer o gráfico de colunas
#tabelaFreq.plot.bar()
#tabelaFreq.plot.barh().set_title('Frequência por especie do recém-nascido')

import scipy.stats as stats
# Histograma
#sns.histplot(dados['petal length (cm)'])
# Selecionar os dados das variáveis

# Correlação de Pearson
# H0 não existe correlação entre as variáveis
X = dados['sepal length (cm)'].values
Y = dados['petal length (cm)'].values
r, p = stats.pearsonr(X, Y)

# Mostrar o resultado
print('Teste de Correlação de Pearson')
print('Pearson r:', r.round(3))
print('p-value:', p.round(3))

# Mostrar um gráfico de dispersão com as duas variáveis
graf1 = sns.regplot(x= dados['sepal length (cm)'], y=dados['petal length (cm)'])
# Formatar os rótulos dos eixos
graf1.set_xlabel("sepal length (cm)")
graf1.set_ylabel("petal length (cm")
# Out:
# testando jupyter
# Obrigado Deus
# God, you are father of all father and you know that
# Have a nice day everyone, iam so happy today
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target species
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# Descricao dos dados
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
url
df = pd.read_csv(url, parse_dates=['Month'], index_col='Month')

df.tail()           # Ultimas observacoes
df.dtypes           # Tipos de variaveis
# Out:
#             Passengers
# Month
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432

# %%
import matplotlib.pyplot as plt
# Plotar a série temporal
plt.figure(figsize=(10,5))
plt.plot(df, label="Consumo de Energia")
plt.xlabel("Ano")
plt.ylabel("Consumo")
plt.legend()
plt.show()
df.dtypes           # Tipos de variaveis
# Criar lag features (valores anteriores)
df['lag1'] = df['Passengers'].shift(1)
df['lag2'] = df['Passengers'].shift(2)

# Remover valores NaN gerados pelo shift
df.dropna(inplace=True)

# Separar X (variáveis preditoras) e y (variável alvo)
X = df[['lag1', 'lag2']]
y = df['Passengers']
